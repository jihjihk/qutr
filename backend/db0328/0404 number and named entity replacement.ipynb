# %%
import pandas as pd
import nltk
import zhon
import re
import plac
import spacy
#nltk.download('maxent_ne_chunker')
#nltk.download('words')

# %%
df = pd.DataFrame(columns=["en","cn","pos"])

# %%
from zhon import hanzi

# %%
count = 0
df = pd.DataFrame(columns=["en","cn","pos"])

with open("./cn_en_phrases/cn_sentences.txt") as f:

    for line in f:
        splitat = 0
        num = ""
        cn = ""
        en = ""
        vp = False

        numarr = re.findall(r"\d[\d,.:：]*", line)
                    
        if numarr:
            for num in numarr:
                line = line.replace(str(num), "*")
                vp = True
        
        for i in range(len(line)):
            if re.findall('[{}]'.format(zhon.hanzi.characters), line[i]):
                splitat = i
                break
                        
        en = line[:splitat-1].strip()
        cn = line[splitat-1:].strip()
        
        df.loc[count, 'en'] = en
        df.loc[count, 'cn'] = cn
        df.loc[count, 'pos'] = "vp" if vp else "sent"
        count += 1

# %%
df.shape
# Out:
# (1006, 3)

# %%
with open("./cn_en_phrases/cn_words.txt") as f:

    for line in f:
        splitat = 0
        num = ""
        cn = ""
        en = ""
        """
        numarr = re.findall(r"\d[\d,.:：]*", line)
                    
        if numarr:
            for num in numarr:
                line = line.replace(str(num), "*")
        
        """
        
        for i in range(len(line)):
            if re.findall('[{}]'.format(zhon.hanzi.characters), line[i]):
                splitat = i
                break
                        
        en = line[:splitat-1].strip().rstrip(".").lower()
        cn = line[splitat-1:].strip().rstrip("。")
        
        df.loc[count, 'en'] = en
        df.loc[count, 'cn'] = cn
        df.loc[count, 'pos'] = "np"
        #print(en)
        #print(cn)
        count += 1

# %%
df.head(50)
# Out:
#                                                    en                      cn  \
# 0                            Morning. May I help you?        早上好，请问有什么可以帮你的吗?
# 1           I would like to make flight reservations.                 我想预订机票。
# 2   I want to book one ticket for the next flight ...       我想预订一张飞往伦敦的下一班机票。
# 3   Would you please make my reservation to Chicag...       请帮我预订明天去芝加哥的机票好吗?
# 4                    Give me a one-way ticket to L.A.           给我一张单程到洛杉矶的票。
# 5   Can I have a second-class one-way ticket to Ch...      请给我一张去芝加哥的单程二等票好吗?
# 6                               When are you leaving?                  您何时出发?
# 7                                  What date, please?                 请问订哪一天?
# 8   I'd like to get three seats on a flight to Par...        我想订*张*月*日到巴黎的机票。
# 9    Do you have any tickets available for that date?               你们有那天的票吗?
# 10       I'd like to take the first available flight.               我想乘第一班飞机。
# 11                 What time does the plane take off?                飞机何时起飞呢?
# 12                     Let me check the availability.               让我看看还有票吗。
# 13             Hold on a second please, Let me see...            请稍等，让我看一下...
# 14  Just a minute and I'll see if there are any fl...         请等一下，让我看看是否有航班。
# 15       Just a second and I will check the schedule.          稍等一会儿，我查一下时间表。
# 16        Just a monent,please. Let me check for you.            请稍等，我来为您查一下。
# 17                                     Yes, there is.                     有的。
# 18  American Airlines has a flight leaving at * a. m.  美国航空公司有一架班机，在早上*点*分起飞。
# 19           We have two flights at * p.m. and * p.m.         我们有两次航班，下午*和*的。
# 20                 Both flights have seats available.                两次航班都有座。
# 21                            There are enough seats.                 还有很多座位。
# 22                             Is it a direct flight?                 是直飞航班吗?
# 23                         Are they non-stop flights?               它们是直飞班机吗?
# 24                              Yes. Direct to Paris.           是的，这是直飞巴黎的飞机。
# 25  We have a nonstop flight leaving at half past ...           *点半我们有一个直达航班。
# 26                       There are no direct flights.                没有直达的航班。
# 27                       That is not a direct flight.               那不是直飞的航班。
# 28                     You need to transfer at Tokyo.               你需要在东京转机。
# 29    Which would you prefer, first class or economy?         你喜欢哪种，头等舱还是经济舱?
# 30  What kind of tickets do you want, first class ...      你要什么类型的票，头等舱还是经济舱?
# 31         Do you want to fly first or economy class?             您要头等舱还是经济舱?
# 32                                        What class?                  要什么舱位?
# 33                                    Business class.                    公务舱。
# 34                                   Economy, please.                  请买经济舱。
# 35   I'll need an economy ticket with an open return.       我要经济舱，回程时间不定的来回票。
# 36           Only first class tickets available, sir.            现在只有头等舱了，先生。
# 37       What's the fare for an economy class ticket?              经济舱的票价是多少?
# 38  What's the fare to New York for the economy cl...           去纽约的经济舱机票多少钱?
# 39                              How much is the fare?                  票价多少钱?
# 40                            How much is the ticket?                  这票多少钱?
# 41                          What is the fare, please?                请问票价是多少?
# 42                       Will this be a one-way trip?                 您要单程票吗?
# 43                             Round trip or one way?                 往返还是单程?
# 44                        How much is the round trip?                 往返票多少钱?
# 45        Do you have any direct flights coming back?           回程时你们有直飞的班机吗?
# 46                                           One way.                     单程。
# 47        Round trip back to Chicago on Janunary *rd.        我要往返票，*月*日飞回芝加哥。
# 48  First class fare of a one-way ticket from Beij...     从北京至上海的单程机票，头等舱是*元。
# 49                                            * yuan.                     *元。
#
#      pos
# 0   sent
# 1   sent
# 2   sent
# 3   sent
# 4   sent
# 5   sent
# 6   sent
# 7   sent
# 8     vp
# 9   sent
# 10  sent
# 11  sent
# 12  sent
# 13  sent
# 14  sent
# 15  sent
# 16  sent
# 17  sent
# 18    vp
# 19    vp
# 20  sent
# 21  sent
# 22  sent
# 23  sent
# 24  sent
# 25    vp
# 26  sent
# 27  sent
# 28  sent
# 29  sent
# 30  sent
# 31  sent
# 32  sent
# 33  sent
# 34  sent
# 35  sent
# 36  sent
# 37  sent
# 38  sent
# 39  sent
# 40  sent
# 41  sent
# 42  sent
# 43  sent
# 44  sent
# 45  sent
# 46  sent
# 47    vp
# 48    vp
# 49    vp

# %%
df.shape
# Out:
# (1670, 3)

# %%
df.to_csv("cn_en_added.csv")

# %% [markdown]
# ---
# # Rerun

# %%
df = pd.read_csv("cn_en_added.csv")
master = pd.read_csv("master0403.csv")

# %%
merge = pd.concat([df, master])

# %%
merge = merge.drop("index", axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-5b71b9a614d2> in <module>()
# ----> 1 merge = merge.drop("index", axis=1)
#
# //anaconda/envs/py3/lib/python3.5/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# //anaconda/envs/py3/lib/python3.5/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    2560                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2561             else:
# -> 2562                 new_axis = axis.drop(labels, errors=errors)
#    2563             dropped = self.reindex(**{axis_name: new_axis})
#    2564             try:
#
# //anaconda/envs/py3/lib/python3.5/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    3742             if errors != 'ignore':
#    3743                 raise ValueError('labels %s not contained in axis' %
# -> 3744                                  labels[mask])
#    3745             indexer = indexer[~mask]
#    3746         return self.delete(indexer)
#
# ValueError: labels ['index'] not contained in axis

# %%
merge = merge.reset_index()

# %%
merge.shape
# Out:
# (2560, 6)

# %%
#merge.to_csv("merged2560.csv")
merge = pd.read_csv("merged2560.csv")

# %%
ne = df.copy()
nlp = spacy.load('en')

# %%
unique = []
for i, row in ne.iterrows():
    try:
        doc = nlp(row.en)
        if doc.ents:
            #print('Name Entity: {0}'.format(doc.ents))
            for ent in doc.ents:
                print("phrase: ", row.en)
                print("NE: ", ent.text)
                my = str(input())
                if my == "*":
                    ne.loc[i,'en'] = ne.loc[i,'en'].replace(ent.text, "*")
                elif my == "":
                    continue
                else:
                    ne.loc[i,'en'] = ne.loc[i,'en'].replace(ent.text, my)
                    
                if ent.text not in unique:
                    unique.append(ent.text)
                    
    except TypeError:
        pass
# Out:
# phrase:  I want to book one ticket for the next flight to London.
# NE:  one
#
# phrase:  I want to book one ticket for the next flight to London.
# NE:  London
# *
# phrase:  Would you please make my reservation to Chicago for tomorrow?
# NE:  Chicago
# *
# phrase:  Would you please make my reservation to Chicago for tomorrow?
# NE:  tomorrow
#
# phrase:  Give me a one-way ticket to L.A.
# NE:  one
#
# phrase:  Give me a one-way ticket to L.A.
# NE:  L.A.
# *
# phrase:  Can I have a second-class one-way ticket to Chicago, please?
# NE:  second
#
# phrase:  Can I have a second-class one-way ticket to Chicago, please?
# NE:  one
#
# phrase:  Can I have a second-class one-way ticket to Chicago, please?
# NE:  Chicago
# *
# phrase:  I'd like to get three seats on a flight to Paris on May *
# NE:  three
# *
# phrase:  I'd like to get three seats on a flight to Paris on May *
# NE:  Paris
# *
# phrase:  I'd like to get three seats on a flight to Paris on May *
# NE:  May
# *
# phrase:  Hold on a second please, Let me see...
# NE:  second
#
# phrase:  Just a minute and I'll see if there are any flights.
# NE:  Just a minute
#
# phrase:  American Airlines has a flight leaving at * a. m.
# NE:  American Airlines
# * airlines
# phrase:  We have two flights at * p.m. and * p.m.
# NE:  two
# *
# phrase:  Yes. Direct to Paris.
# NE:  Paris
# *
# phrase:  We have a nonstop flight leaving at half past ten.
# NE:  half past ten
# *
# phrase:  You need to transfer at Tokyo.
# NE:  Tokyo
# *
# phrase:  Which would you prefer, first class or economy?
# NE:  first
#
# phrase:  Do you want to fly first or economy class?
# NE:  first
#
# phrase:  Only first class tickets available, sir.
# NE:  first
#
# phrase:  What's the fare to New York for the economy class?
# NE:  New York
# *
# phrase:  Will this be a one-way trip?
# NE:  one
#
# phrase:  Round trip or one way?
# NE:  one
#
# phrase:  One way.
# NE:  One
#
# phrase:  Round trip back to Chicago on Janunary *rd.
# NE:  Chicago
# *
# phrase:  Round trip back to Chicago on Janunary *rd.
# NE:  Janunary
# *
# phrase:  First class fare of a one-way ticket from Beijing to Shanghai is * yuan.
# NE:  First
#
# phrase:  First class fare of a one-way ticket from Beijing to Shanghai is * yuan.
# NE:  one
#
# phrase:  First class fare of a one-way ticket from Beijing to Shanghai is * yuan.
# NE:  Beijing
# *
# phrase:  First class fare of a one-way ticket from Beijing to Shanghai is * yuan.
# NE:  Shanghai
# *
# phrase:  Sure! I'm Liuxia. My phone number is * and ID number is *
# NE:  Liuxia
# *
# phrase:  Your flight number is BT*
# NE:  BT
# *
# phrase:  Your seat is confirmed on flight BT* leaving at *
# NE:  BT
# *
# phrase:  Come to pay the fare and fetch your ticket two days before departure, please.
# NE:  two days
# * days
# phrase:  You have to be there two hours before departure time.
# NE:  two hours
# * hours
# phrase:  Please check in at the airport two hours before departure.
# NE:  the airport two hours
#
# phrase:  Please be there fourteen o'clock at the latest.
# NE:  fourteen o'clock
# *
# phrase:  You'll have to get there by * at the latest. The check-in is half an hour earlier than departure.
# NE:  half an hour earlier
#
# phrase:  You have to be there half an hour before departure time.
# NE:  there half an hour
#
# phrase:  I'd like to cancel my reservation for the flight on September * and book one on September * instead, please.
# NE:  September
#
# phrase:  I'd like to cancel my reservation for the flight on September * and book one on September * instead, please.
# NE:  one
#
# phrase:  I'd like to cancel my reservation for the flight on September * and book one on September * instead, please.
# NE:  September
# *
# phrase:  What about September *?
# NE:  September
# *
# phrase:  Let me see. OK, there is only one ticket left, first class and it is * yuan.
# NE:  only one
#
# phrase:  Let me see. OK, there is only one ticket left, first class and it is * yuan.
# NE:  first
#
# phrase:  Yes, for September * * yuan, OK?
# NE:  September
# *
# phrase:  Where is the check-in counter for China Airlines?
# NE:  China Airlines
# * Airlines
# phrase:  May I check in here for flight MU * to Tokyo?
# NE:  Tokyo
# *
# phrase:  Please check-in at zone R.
# NE:  R.
# *
# phrase:  You may check in at the self-service kiosk area in zones G & H.
# NE:  G & H.
# *
# phrase:  Please queue for flights to European destinations.
# NE:  European
# *
# phrase:  One economy class seat, is that right
# NE:  One
#
# phrase:  You'll be boarding at Gate *
# NE:  Gate
#
# phrase:  No, Miss. Just show your ticket to the boarding officer as you get on the plane.
# NE:  Miss.
# Sir/Madam
# phrase:  Please pass through the detector one by one.
# NE:  one
#
# phrase:  Please pass through the detector one by one.
# NE:  one
#
# phrase:  We could check it in for you ,or you could have it deposited temporarily at our place for up to one month.
# NE:  up to one month
#
# phrase:  If you can't come back within a month, we won't keep it for you.
# NE:  a month
#
# phrase:  Attention, please. Due to weather condition, all flights to Taipei will be delayed.
# NE:  Taipei
# *
# phrase:  Flight *-bound for Philadelphia.
# NE:  Philadelphia
# *
# phrase:  Probably not more than two hours.
# NE:  more than two hours
# * hours
# phrase:  Just a minute. Let me check.
# NE:  Just a minute
#
# phrase:  Yes, there is a flight leaving for Philadelphia in ten minutes, but it's full. I could put you on standby if you wish.
# NE:  Philadelphia
# *
# phrase:  Yes, there is a flight leaving for Philadelphia in ten minutes, but it's full. I could put you on standby if you wish.
# NE:  ten minutes
# *
# phrase:  Yes, all right. But if I don't get on that flight, would it be possible to change the connecting flight to Miami?
# NE:  Miami
# *
# phrase:  Let's see... there's a United flight leaving Philadelphia at * this evening.
# NE:  United
# * Airlines
# phrase:  Let's see... there's a United flight leaving Philadelphia at * this evening.
# NE:  Philadelphia
# *
# phrase:  Let's see... there's a United flight leaving Philadelphia at * this evening.
# NE:  this evening
#
# phrase:  Departure Gate.
# NE:  Departure Gate
#
# phrase:  The next flight available for boarding is to Lincoln, Nebraska.
# NE:  Lincoln
# *
# phrase:  The next flight available for boarding is to Lincoln, Nebraska.
# NE:  Nebraska
#
# phrase:  Thai Airlines flight TG * to Bangkok is now boarding.
# NE:  Thai Airlines
# * Airlines
# phrase:  Thai Airlines flight TG * to Bangkok is now boarding.
# NE:  TG
# *
# phrase:  Thai Airlines flight TG * to Bangkok is now boarding.
# NE:  Bangkok
# *
# phrase:  Passengers in the first class, please proceed to the boarding gate now.
# NE:  first
#
# phrase:  Terminal * & Cargo.
# NE:  Terminal * & Cargo
#
# phrase:  Waiting Lounge.
# NE:  Waiting Lounge
#
# phrase:  Departure Lounge.
# NE:  Departure Lounge
#
# phrase:  Lounge Pavilion.
# NE:  Lounge Pavilion
#
# phrase:  Area Of Customs Control.
# NE:  Area Of Customs Control
#
# phrase:  Customs Declaration form.
# NE:  Customs Declaration
#
# phrase:  Customs Declaration Counter.
# NE:  Customs
#
# phrase:  Security Office.
# NE:  Security Office
#
# phrase:  Trolley.
# NE:  Trolley
#
# phrase:  Luggage Storage (Counter).
# NE:  Luggage Storage
#
# phrase:  Luggage Storage (Counter).
# NE:  Counter
#
# phrase:  Baggage Rack.
# NE:  Baggage Rack
#
# phrase:  Luggage Inspection.
# NE:  Luggage Inspection
#
# phrase:  Luggage Delivery.
# NE:  Luggage Delivery
#
# phrase:  Goods Prohibited To Be Hand-Carried.
# NE:  Goods Prohibited
#
# phrase:  Goods Prohibited To Exit The Country.
# NE:  Goods Prohibited
#
# phrase:  Emergency Exit.
# NE:  Emergency Exit
#
# phrase:  Missing People Help Line.
# NE:  Missing People Help Line
#
# phrase:  Lost Child Information.
# NE:  Lost Child Information
#
# phrase:  Departure Time On Reverse.
# NE:  Departure Time
#
# phrase:  Do you have Chinese newspapers?
# NE:  Chinese
# *
# phrase:  Excuse me. What would you like to eat, Chinese food or Western food?
# NE:  Chinese
# * cuisine
# phrase:  Excuse me. What would you like to eat, Chinese food or Western food?
# NE:  Western
# /
# phrase:  What is the Chinese food?
# NE:  Chinese
# *
# phrase:  Porridge.
# NE:  Porridge
#
# phrase:  One extra pillow, please.
# NE:  One
#
# phrase:  Could you give me one more blanket?
# NE:  one
#
# phrase:  We will be landing at Bangkok international Airport in * minutes.
# NE:  Bangkok
# *
# phrase:  We will be landing at Bangkok international Airport in * minutes.
# NE:  Airport
#
# phrase:  We will be landing at Bangkok international Airport in * minutes.
# NE:  minutes
#
# phrase:  Captain Tony and all the members of his crew thank you for flying with us.
# NE:  Tony
# *
# phrase:  I am going to transfer in Hong Kong.
# NE:  Hong Kong
# *
# phrase:  I have to transfer to New York.
# NE:  New York
# *
# phrase:  Where is the CAL transfer desk?
# NE:  CAL
# * Airlines
# phrase:  Which carousel is for flight TG *? TG
# NE:  TG
# *
# phrase:  Fill out this form.
# NE:  Fill
#
# phrase:  The restaurant is so popular that you have to wait for one to two hours to get a seat.
# NE:  one to two hours
#
# phrase:  This restaurant is more expensive than that one.
# NE:  one
#
# phrase:  Let's choose the least expensive restaurant today.
# NE:  today
#
# phrase:  Good evening. Welcome to our restaurant.
# NE:  evening
#
# phrase:  I've reserved a table for two.
# NE:  two
# *
# phrase:  I have a reservation under Peter Li.
# NE:  Peter Li
# *
# phrase:  My surname is Victor.
# NE:  Victor
# *
# phrase:  The name is Victor.
# NE:  Victor
# *
# phrase:  A table for three, please.
# NE:  three
# *
# phrase:  We'd love a table for four.
# NE:  four
# *
# phrase:  We need a table for four.
# NE:  four
# *
# phrase:  Do you have a table for four please?
# NE:  four
# *
# phrase:  Please wait a moment.
# NE:  a moment
#
# phrase:  The one by the window has been taken by others.
# NE:  one
#
# phrase:  You may look at the menu first and decide what you like to have.
# NE:  first
#
# phrase:  Our waitress will get you tea in a minute.
# NE:  a minute
#
# phrase:  We've been waiting for an hour.
# NE:  an hour
#
# phrase:  I've been waiting half an hour for my order.
# NE:  half an hour
#
# phrase:  We came here before they did. How come they were served first?
# NE:  first
#
# phrase:  The kitchen is very busy today.
# NE:  today
#
# phrase:  I want three doggy bags.
# NE:  three
# *
# phrase:  Many cafes are now equipped with Wi-Fi.
# NE:  Wi-Fi
#
# phrase:  I love Japanese coffee shops.
# NE:  Japanese
# *
# phrase:  Give me two pieces of cake.
# NE:  two
# *
# phrase:  Can you come here when you have a second?
# NE:  second
#
# phrase:  We lazed the whole afternoon away at a cafe.
# NE:  afternoon
#
# phrase:  The Pearl River Hotel. anything I can do for you?
# NE:  The Pearl River Hotel
# It's *
# phrase:  Room Reservation. Good afternoon.
# NE:  afternoon
#
# phrase:  For the night of April *th for one night.
# NE:  the night
#
# phrase:  For the night of April *th for one night.
# NE:  April
# *
# phrase:  For the night of April *th for one night.
# NE:  one night
# * night(s)
# phrase:  I'd like to book a single room with a bath from the afternoon of February *th to the morning of february *th.
# NE:  the afternoon
#
# phrase:  I'd like to book a single room with a bath from the afternoon of February *th to the morning of february *th.
# NE:  February
# *
# phrase:  I'm calling from Nanjing. I'd like to reserve a single room from tomorrow for six days, please.
# NE:  Nanjing
# *
# phrase:  I'm calling from Nanjing. I'd like to reserve a single room from tomorrow for six days, please.
# NE:  tomorrow
#
# phrase:  I'm calling from Nanjing. I'd like to reserve a single room from tomorrow for six days, please.
# NE:  six days
# * day(s)
# phrase:  I'd like to book a double room for next Tuesday.
# NE:  next Tuesday
# *
# phrase:  That's fine. A double room for Tuesday, September *th.
# NE:  Tuesday, September
# *
# phrase:  We'll be leaving on Sunday morning.
# NE:  Sunday morning
# * morning
# phrase:  That will be five night.
# NE:  five night
# * night(s)
# phrase:  Could you hold the line, please? I'll check our room availability for that day.
# NE:  that day
#
# phrase:  It's two hundred and twenty yuan per night.
# NE:  two hundred
# *
# phrase:  It's two hundred and twenty yuan per night.
# NE:  twenty yuan
# *
# phrase:  Yes, it is Carl.
# NE:  Carl
# *
# phrase:  I'll get there by five o'clock on August *th.
# NE:  five o'clock
# *
# phrase:  I'll get there by five o'clock on August *th.
# NE:  August
# *
# phrase:  We look forward to seeing you next Tuesday.
# NE:  next Tuesday
# on *.
# phrase:  I'm afraid our hotel is fully booked on that night.
# NE:  that night
#
# phrase:  Room Reservations. May i help you,sir?
# NE:  Room Reservations
#
# phrase:  Room Reservations. May i help you,sir?
# NE:  May
#
# phrase:  Yes, my name is Alice, and I made a reservation for two nights from October *th. I'd like to extend it for two more nights until the *th.
# NE:  Alice
# *
# phrase:  Yes, my name is Alice, and I made a reservation for two nights from October *th. I'd like to extend it for two more nights until the *th.
# NE:  two nights from October
# *BREAK*
# phrase:  Yes, my name is Alice, and I made a reservation for two nights from October *th. I'd like to extend it for two more nights until the *th.
# NE:  two
#
# phrase:  For * nights from October *th until October *th.
# NE:  nights
#
# phrase:  For * nights from October *th until October *th.
# NE:  October
# *
# phrase:  For * nights from October *th until October *th.
# NE:  October
# *
# phrase:  I booked a single room in your hotel for this friday.
# NE:  this friday
# *
# phrase:  Jack Bruder.
# NE:  Jack Bruder
# *BREAK*
# phrase:  From October *nd for * nights.
# NE:  October
# *
# phrase:  From October *nd for * nights.
# NE:  nights
#
# phrase:  It's Mary Calson and my number is *-*
# NE:  Mary Calson
# *
# phrase:  Thank you, ma'am.I'll cancel Mr.Bruder's reservation from October *nd for * nights.My name is Jason and we look forward to another chance to serve you.
# NE:  October
# *BREAK*
# phrase:  Thank you, ma'am.I'll cancel Mr.Bruder's reservation from October *nd for * nights.My name is Jason and we look forward to another chance to serve you.
# NE:  nights
#
# phrase:  Thank you, ma'am.I'll cancel Mr.Bruder's reservation from October *nd for * nights.My name is Jason and we look forward to another chance to serve you.
# NE:  Jason
#
# phrase:  Front Desk
# NE:  Front Desk
#
# phrase:  Front Counter
# NE:  Front Counter
#
# phrase:  Front Aisle
# NE:  Front Aisle
#
# phrase:  West Wing
# NE:  West Wing
#
# phrase:  East Box
# NE:  East Box
#
# phrase:  West Box
# NE:  West Box
#
# phrase:  Accessible Guestroom.
# NE:  Accessible Guestroom
#
# phrase:  House Keeping Dept.
# NE:  House
#
# phrase:  No Service Fee.
# NE:  No Service Fee
#
# phrase:  Guest Safety Tips.
# NE:  Guest Safety Tips
#
# phrase:  Always Use Deadbolt.
# NE:  Deadbolt
#
# phrase:  Insert Or Swipe Key.
# NE:  Insert
#
# phrase:  Insert Or Swipe Key.
# NE:  Swipe Key
#
# phrase:  Remove Key.
# NE:  Remove Key
#
# phrase:  A Cleaning Fee Of $* Will Be Charged To Your Room Account If You Smoke In This Room.
# NE:  Cleaning Fee Of $
# Cleaning Fee of
# phrase:  A Cleaning Fee Of $* Will Be Charged To Your Room Account If You Smoke In This Room.
# NE:  You Smoke
#
# phrase:  In-Room Coffee Maker.
# NE:  Room Coffee Maker
#
# phrase:  Be Careful When Using The Bath.
# NE:  Bath
#
# phrase:  Outdoor Swimming Pools.
# NE:  Outdoor Swimming Pools
#
# phrase:  Indoor Swimming Pools.
# NE:  Indoor Swimming Pools
#
# phrase:  (Hair) Dryer
# NE:  Hair) Dryer
#
# phrase:  Warm Air Hand Drier.
# NE:  Warm Air Hand Drier
#
# phrase:  Shave Pins In All Bedrooms.
# NE:  Bedrooms
#
# phrase:  Warn Children Of The Risk Of Death By Electric Shock.
# NE:  Warn Children
#
# phrase:  Warn Children Of The Risk Of Death By Electric Shock.
# NE:  The Risk Of Death By Electric Shock
#
# phrase:  If You Forget To Pack Any Standard Toiletry Item（Toothbrush, Toothpaste, Shaving Cream, Razor Or Comb）, Just Call The Front Desk And We'll Get You A Complimentary Repacement Right Away.
# NE:  Toothpaste
#
# phrase:  If You Forget To Pack Any Standard Toiletry Item（Toothbrush, Toothpaste, Shaving Cream, Razor Or Comb）, Just Call The Front Desk And We'll Get You A Complimentary Repacement Right Away.
# NE:  Razor Or Comb
#
# phrase:  If You Forget To Pack Any Standard Toiletry Item（Toothbrush, Toothpaste, Shaving Cream, Razor Or Comb）, Just Call The Front Desk And We'll Get You A Complimentary Repacement Right Away.
# NE:  The Front Desk
#
# phrase:  For Your Convenience, Cigarettes Are Available At The Front Desk.
# NE:  The Front Desk
#
# phrase:  Laundry Service.
# NE:  Laundry Service
#
# phrase:  Early Book For Lunch Or Dinner.
# NE:  Early Book For Lunch Or Dinner
#
# phrase:  Wifi Is Available In Public Area In The Hotel.
# NE:  Hotel
#
# phrase:  Please Call The Hotel Operator For More Information.
# NE:  The Hotel Operator For More Information
#
# phrase:  Two Way Traffic Hotel Parking.
# NE:  Two
#
# phrase:  Executive Business Centre.
# NE:  Executive Business Centre
#
# phrase:  Restaurant And Pub.
# NE:  Pub
#
# phrase:  Fitness Centre.
# NE:  Fitness Centre
#
# phrase:  Exercise Facilities
# NE:  Exercise Facilities
#
# phrase:  Four people.
# NE:  Four
# *
# phrase:  Do you speak Japanese?
# NE:  Japanese
# *
# phrase:  I only speak English.
# NE:  English
# *
# phrase:  What sort of job do you do at ABC?
# NE:  ABC
# *
# phrase:  I want you to meet Bob.
# NE:  Bob
# *
# phrase:  I'd like to introduce Bob.
# NE:  Bob
# *
# phrase:  I'm * years old.
# NE:  years old
#
# phrase:  I come from Canada.
# NE:  Canada
# *
# phrase:  My nationality is Chinese.
# NE:  Chinese
# *
# phrase:  I am American.
# NE:  American
# *
# phrase:  Is the supermarket open today?
# NE:  today
#
# phrase:  Let's get a shopping cart first.
# NE:  first
#
# phrase:  Can anyone tell me where I can buy the ingredients to make Chinese food?
# NE:  Chinese
# *
# phrase:  Slice me half a kilo of beef.
# NE:  half
# *
# phrase:  We have a clearance sale today.
# NE:  today
#
# phrase:  first class
# NE:  first
#
# phrase:  children and women first
# NE:  first
#
# phrase:  one-way ticket
# NE:  one
#
# phrase:  safety first
# NE:  first
#
# phrase:  first name
# NE:  first
#
# phrase:  hawaiian kona coffee
# NE:  hawaiian
#
# phrase:  academic year
# NE:  year
#
# phrase:  second job
# NE:  second

# %%
ne
# Out:
#       Unnamed: 0                                                 en  \
# 0              0                           Morning. May I help you?
# 1              1          I would like to make flight reservations.
# 2              2  I want to book one ticket for the next flight ...
# 3              3  Would you please make my reservation to * for ...
# 4              4                      Give me a one-way ticket to *
# 5              5  Can I have a second-class one-way ticket to *,...
# 6              6                              When are you leaving?
# 7              7                                 What date, please?
# 8              8    I'd like to get * seats on a flight to * on * *
# 9              9   Do you have any tickets available for that date?
# 10            10       I'd like to take the first available flight.
# 11            11                 What time does the plane take off?
# 12            12                     Let me check the availability.
# 13            13             Hold on a second please, Let me see...
# 14            14  Just a minute and I'll see if there are any fl...
# 15            15       Just a second and I will check the schedule.
# 16            16        Just a monent,please. Let me check for you.
# 17            17                                     Yes, there is.
# 18            18         * airlines has a flight leaving at * a. m.
# 19            19             We have * flights at * p.m. and * p.m.
# 20            20                 Both flights have seats available.
# 21            21                            There are enough seats.
# 22            22                             Is it a direct flight?
# 23            23                         Are they non-stop flights?
# 24            24                                  Yes. Direct to *.
# 25            25             We have a nonstop flight leaving at *.
# 26            26                       There are no direct flights.
# 27            27                       That is not a direct flight.
# 28            28                         You need to transfer at *.
# 29            29    Which would you prefer, first class or economy?
# ...          ...                                                ...
# 1640        1640                                         ex-husband
# 1641        1641                                            ex-wife
# 1642        1642                                       elder brothe
# 1643        1643                                             sister
# 1644        1644                                     younger sister
# 1645        1645                                        stepbrother
# 1646        1646                                             cousin
# 1647        1647                                      sister-in-law
# 1648        1648                                                son
# 1649        1649                                            stepson
# 1650        1650                                        adopted son
# 1651        1651                                    daughter-in-law
# 1652        1652                                             nephew
# 1653        1653                                             father
# 1654        1654                                                dad
# 1655        1655                                         stepfather
# 1656        1656                                      foster father
# 1657        1657                                      father-in-law
# 1658        1658                                              uncle
# 1659        1659                                        grandmother
# 1660        1660                                            grandma
# 1661        1661                                           grandson
# 1662        1662                                  great-grandmother
# 1663        1663                                         great-aunt
# 1664        1664                                great-granddaughter
# 1665        1665                                           marriage
# 1666        1666                                             female
# 1667        1667                                            descent
# 1668        1668                                           ancestor
# 1669        1669                                               heir
#
#                           cn   pos
# 0           早上好，请问有什么可以帮你的吗?  sent
# 1                    我想预订机票。  sent
# 2          我想预订一张飞往伦敦的下一班机票。  sent
# 3          请帮我预订明天去芝加哥的机票好吗?  sent
# 4              给我一张单程到洛杉矶的票。  sent
# 5         请给我一张去芝加哥的单程二等票好吗?  sent
# 6                     您何时出发?  sent
# 7                    请问订哪一天?  sent
# 8           我想订*张*月*日到巴黎的机票。    vp
# 9                  你们有那天的票吗?  sent
# 10                 我想乘第一班飞机。  sent
# 11                  飞机何时起飞呢?  sent
# 12                 让我看看还有票吗。  sent
# 13              请稍等，让我看一下...  sent
# 14           请等一下，让我看看是否有航班。  sent
# 15            稍等一会儿，我查一下时间表。  sent
# 16              请稍等，我来为您查一下。  sent
# 17                       有的。  sent
# 18    美国航空公司有一架班机，在早上*点*分起飞。    vp
# 19           我们有两次航班，下午*和*的。    vp
# 20                  两次航班都有座。  sent
# 21                   还有很多座位。  sent
# 22                   是直飞航班吗?  sent
# 23                 它们是直飞班机吗?  sent
# 24             是的，这是直飞巴黎的飞机。  sent
# 25             *点半我们有一个直达航班。    vp
# 26                  没有直达的航班。  sent
# 27                 那不是直飞的航班。  sent
# 28                 你需要在东京转机。  sent
# 29           你喜欢哪种，头等舱还是经济舱?  sent
# ...                      ...   ...
# 1640                      前夫    np
# 1641                      前妻    np
# 1642                      哥哥    np
# 1643                      姐妹    np
# 1644                      妹妹    np
# 1645                异父(母)之兄弟    np
# 1646                 堂兄妹，表兄妹    np
# 1647                      弟妹    np
# 1648                      儿子    np
# 1649                      继子    np
# 1650                      养子    np
# 1651                      儿媳    np
# 1652                   侄儿，外甥    np
# 1653                      父亲    np
# 1654                      爸爸    np
# 1655                      继父    np
# 1656                      养父    np
# 1657                   岳父，公公    np
# 1658             叔父，伯父，舅父，姑父    np
# 1659                      祖母    np
# 1660                      奶奶    np
# 1661                      孙子    np
# 1662                     曾祖母    np
# 1663                   叔、伯祖母    np
# 1664                曾孙女，曾外孙女    np
# 1665                      婚姻    np
# 1666                      女的    np
# 1667                   世系，血统    np
# 1668                      祖先    np
# 1669                     继承人    np
#
# [1670 rows x 4 columns]

# %% [markdown]
# ## Database checklist
#
# * \*BREAK* check
# * Chinese named entity removal
# * multiple definition check
# * POS tag check
# * 60 + dollars -> 60 dollars BUT dollars + 60 -> dollars w/o number
#
# ---
#
# ## Template options
#
# * pronoun
# * proper noun
# * location
# * time

# %%
copy = ne.copy()
copy.sort_values(by='en', inplace=True)
copy.drop('Unnamed: 0', axis=1, inplace=True)
copy.head()
# Out:
#                                               en                      cn   pos
# 856                                 (Hair) Dryer                   头发吹风机  sent
# 222  * Airlines flight * * to * is now boarding.     飞往曼谷的泰航TG*班，已经开始登机。    vp
# 18    * airlines has a flight leaving at * a. m.  美国航空公司有一架班机，在早上*点*分起飞。    vp
# 898                                    * people.                    四口人。  sent
# 49                                       * yuan.                     *元。    vp

# %%
master = pd.read_csv("master0403.csv")
#master.drop('ar', axis=1, inplace=True)
m1 = pd.concat([master, copy])

# %%
#m1.drop("Unnamed: 0", axis=1, inplace=True)
m1.sort_values(by='en', inplace=True)
m1 = m1[['en', 'cn', 'ar', 'pos']]
m1.to_csv("m1.tsv", sep="\t")

# %% [markdown]
# # Cleaned and merged 2500 phrases

# %%
clean = pd.read_csv("clean2500-0410.csv")

# %%
clean.shape
# Out:
# (2473, 4)

# %%
clean.head()
# Out:
#                                       en                cn  \
# 0                                 * a.m.              下午*点
# 1  * airlines has a flight leaving at *.  *航空公司有一架班机，在*起飞。
# 2                      * and * , please.           请给我*和*。
# 3                               * day(s)                *天
# 4                                * dinar               第纳尔
#
#                      ar  pos
# 0              * صباحًا  prt
# 1                   NaN   vp
# 2  من فضلك أعطني * و *.   vp
# 3               ‏* أيام  prt
# 4                 دينار  prt

# %%
clean.ar.fillna("")
# Out:
# 0                   * صباحًا
# 1
# 2       من فضلك أعطني * و *.
# 3                    ‏* أيام
# 4                      دينار
# 5                       درهم
# 6                      دولار
# 7                   ‏* ساعات
# 8                  * لا يعمل
# 9                   ‏* دقائق
# 10                   *  أشهر
# 11                   * مساءً
# 12                   * أشخاص
# 13
# 14                      جنيه
# 15                  ‏* أسبوع
# 16                  ‏* سنوات
# 17                    * يوان
# 18
# 19                    قارورة
# 20
# 21
# 22
# 23             كأس من النبيذ
# 24                   نصف لتر
# 25
# 26             طاولة ل * شخص
# 27
# 28
# 29                       بطن
#                 ...
# 2443
# 2444
# 2445
# 2446
# 2447
# 2448               أنت تغشني
# 2449        على الرحب والسعة
# 2450
# 2451
# 2452
# 2453
# 2454
# 2455
# 2456
# 2457
# 2458
# 2459
# 2460
# 2461
# 2462
# 2463
# 2464
# 2465             بيوت الشباب
# 2466                    زغرب
# 2467                  زامبيا
# 2468                     صفر
# 2469                زيمبابوي
# 2470                  زيوريخ
# 2471
# 2472
# Name: ar, Length: 2473, dtype: object

# %%
clean[clean.duplicated(['en'], keep="first")]
# Out:
#                       en     cn    ar   pos
# 1505  nothing to declare  无申报通道   NaN    np
# 1551                open     打开  لفتح    vp
# 2472                 NaN    NaN   NaN  sent

# %%
clean.loc[1551,'en'] = "to open"

# %%
clean.drop(2472, inplace=True)

# %%
for i, word in clean.iterrows():
    #if not str(i)[0].isalpha():
    if word.cn == ".你可以走了，带好你的东西。":
        print(i)
# Out:
# 2441

# %%
clean.iloc[2441]
# Out:
# en     You may go now. Please take your things
# cn                              .你可以走了，带好你的东西。
# ar                                         NaN
# pos                                       sent
# Name: 2441, dtype: object

# %%
clean.loc[2441,'cn']="你可以走了，带好你的东西。"
clean.loc[2441,'en']="You may go now. Please take your things."

# %%
clean = clean.reset_index()
clean.drop('index', axis=1,inplace=True)

# %%
clean.drop('level_0', axis=1,inplace=True)
clean.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-d5a15005f75c> in <module>()
# ----> 1 clean.drop('level_0', axis=1,inplace=True)
#       2 clean.head()
#
# //anaconda/envs/py3/lib/python3.5/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# //anaconda/envs/py3/lib/python3.5/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    2560                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2561             else:
# -> 2562                 new_axis = axis.drop(labels, errors=errors)
#    2563             dropped = self.reindex(**{axis_name: new_axis})
#    2564             try:
#
# //anaconda/envs/py3/lib/python3.5/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    3742             if errors != 'ignore':
#    3743                 raise ValueError('labels %s not contained in axis' %
# -> 3744                                  labels[mask])
#    3745             indexer = indexer[~mask]
#    3746         return self.delete(indexer)
#
# ValueError: labels ['level_0'] not contained in axis

# %%
clean.sort_values('en')
clean.drop(2471, inplace=True)

# %%
clean.to_csv("cleaned0410.csv")

# %%
clean.drop([26], inplace=True)

# %%
for i,row in clean.iterrows():
    if row.pos == "adv":
        print(row)
# Out:
# en     after
# cn        之后
# ar       بعد
# pos      adv
# Name: 48, dtype: object
# en     before
# cn         以前
# ar        قبل
# pos       adv
# Name: 166, dtype: object
# en     here
# cn       这里
# ar      هنا
# pos     adv
# Name: 831, dtype: object
# en      later
# cn        迟一点
# ar     لاحقاً
# pos       adv
# Name: 1255, dtype: object
# en     left
# cn       左边
# ar     يسار
# pos     adv
# Name: 1264, dtype: object
# en     north
# cn         北
# ar      شمال
# pos      adv
# Name: 1497, dtype: object
# en      now
# cn       现在
# ar     الآن
# pos     adv
# Name: 1509, dtype: object
# en        one way
# cn            单行道
# ar     اتجاه واحد
# pos           adv
# Name: 1545, dtype: object
# en     Please.
# cn          请。
# ar     من فضلك
# pos        adv
# Name: 1663, dtype: object
# en     slowly
# cn        慢慢的
# ar       ببطء
# pos       adv
# Name: 1828, dtype: object
# en     south
# cn         南
# ar      جنوب
# pos      adv
# Name: 1854, dtype: object
# en     there
# cn        那里
# ar      هناك
# pos      adv
# Name: 1995, dtype: object
# en     west
# cn        西
# ar      غرب
# pos     adv
# Name: 2224, dtype: object

# %%
clean.loc[2065, "en"] = "To *."
clean.loc[2065, "cn"] = "去*。"
clean.loc[2065, "ar"] = "إلى *."
clean.loc[2065, "pos"] = "vp"

# %%
clean.loc[2065]
# Out:
# en      To *.
# cn        去*。
# ar     إلى *.
# pos        vp
# Name: 2065, dtype: object

# %%
clean.to_csv("cleaned0410.csv")

# %% [markdown]
# ## Note: only vp and prt can contain *

# %%
clean.head()
# Out:
#                                       en                cn  \
# 0                                 * a.m.              下午*点
# 1  * airlines has a flight leaving at *.  *航空公司有一架班机，在*起飞。
# 2                      * and * , please.           请给我*和*。
# 3                               * day(s)                *天
# 4                                * dinar               第纳尔
#
#                      ar  pos
# 0              * صباحًا  prt
# 1                   NaN   vp
# 2  من فضلك أعطني * و *.   vp
# 3               ‏* أيام  prt
# 4                 دينار  prt
