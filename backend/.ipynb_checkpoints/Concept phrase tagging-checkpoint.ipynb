# %% [markdown]
# ---
#
# # Basic sentence generation using a list of IDs as input
# ## Concept ID Database
#
# ### POS for qutr
#
# * sent: complete sentences and greetings
# * vp: verb phrases to refer to sentence templates with empty noun phrases
# * np: noun and noun phrases
# * adj: adjective
# * adv: adverb
# * conj: conjunctions
# * prt: particles or other function words
# * num: cardinal numbers
# * X: other
#
# "A Universal Part-of-Speech Tagset" by Slav Petrov, Dipanjan Das and Ryan McDonald

# %%
import pandas as pd

# %%
tri = pd.read_csv("basic_tri_db.csv")

# %%
pos = ["phrs","phrs","phrs","phrs","phrs","phrs","phrs","phrs","vp","phrs","adj","adv","adv","vp","np","np","np","vp","phrs","prt","prt","vp","prt","adv","phrs","phrs","phrs","phrs","phrs","phrs","phrs","adj","adj","phrs","phrs","vp","phrs","conj","phrs","vp","phrs"]

# %%
en = pd.DataFrame(tri.en)
ar = pd.DataFrame(tri.ar)
cn = pd.DataFrame(tri.cn)

en = en.rename(columns={"en":"phrase"})
ar = ar.rename(columns={"ar":"phrase"})
cn = cn.rename(columns={"cn":"phrase"})

for langdf in [en, ar, cn]:
    langdf['pos'] = pos
    for i in range(0, len(langdf)):
        ## assigning a new index col with p0, p1... to differentiate string IDs with cardinal numbers
        langdf.loc[i, 'id'] = "p" + str(i)
    langdf.set_index("id", inplace=True)

# %%
en
# Out:
#                             phrase   pos
# id
# p0                           Hello  phrs
# p1                              Hi  phrs
# p2                         Welcome  phrs
# p3                    Good Morning  phrs
# p4                  Good Afternoon  phrs
# p5                    Good Evening  phrs
# p6            What would you like?  phrs
# p7              What is your name?  phrs
# p8                    My name is *    vp
# p9                Nice to meet you  phrs
# p10                           good   adj
# p11                         very *   adv
# p12                          Today   adv
# p13                      We have *    vp
# p14                         Orange    np
# p15                          Apple    np
# p16                          Mango    np
# p17                How much are *?    vp
# p18             What is the price?  phrs
# p19                      * dollars   prt
# p20                          per *   prt
# p21                 I would like *    vp
# p22                    * kilograms   prt
# p23                         please   adv
# p24                           okay  phrs
# p25  Would you like anything else?  phrs
# p26                            Yes  phrs
# p27                             No  phrs
# p28                     No, thanks  phrs
# p29               I don't need it.  phrs
# p30                       Good bye  phrs
# p31                          Right   adj
# p32                          Wrong   adj
# p33                      Thank you  phrs
# p34                You are welcome  phrs
# p35                 Do you have *?    vp
# p36            I do not understand  phrs
# p37                            and  conj
# p38                          Sorry  phrs
# p39                Do you speak *?    vp
# p40                          Help!  phrs

# %%
cn
# Out:
#        phrase   pos
# id
# p0         你好  phrs
# p1         您好  phrs
# p2         欢迎  phrs
# p3        早上好  phrs
# p4        下午好  phrs
# p5        晚上好  phrs
# p6     你需要什么？  phrs
# p7    你叫什么名字？  phrs
# p8        我叫*    vp
# p9     很高兴见到你  phrs
# p10         好   adj
# p11        很*   adv
# p12        今天   adv
# p13        有*    vp
# p14        橘子    np
# p15        苹果    np
# p16        芒果    np
# p17     *多少钱？    vp
# p18      多少钱？  phrs
# p19       *块钱   prt
# p20   每QUANT*   prt
# p21       我要*    vp
# p22       *公斤   prt
# p23         请   adv
# p24         好  phrs
# p25  你还需要什么吗？  phrs
# p26        是的  phrs
# p27        不是  phrs
# p28    不用了，谢谢  phrs
# p29        不要  phrs
# p30        再见  phrs
# p31         对   adj
# p32        不对   adj
# p33        谢谢  phrs
# p34       不用谢  phrs
# p35     有没有*？    vp
# p36      我听不懂  phrs
# p37         和  conj
# p38       对不起  phrs
# p39    你会说*吗？    vp
# p40      帮帮我！  phrs

# %%
ar
# Out:
#                   phrase   pos
# id
# p0                  أهلا  phrs
# p1                مرحبا   phrs
# p2          السلام عليكم  phrs
# p3            صباح الخير  phrs
# p4             طاب مسائك  phrs
# p5            مساء الخير  phrs
# p6             ماذا تحب؟  phrs
# p7              ما اسمك؟  phrs
# p8                اسمي *    vp
# p9                تشرفنا  phrs
# p10                  جيد   adj
# p11                 *جدا   adv
# p12                اليوم   adv
# p13              لدينا *    vp
# p14               برتقال    np
# p15                 تفاح    np
# p16                مانجو    np
# p17             كم هي *؟    vp
# p18          ماهو السعر؟  phrs
# p19            * دولارات   prt
# p20                لكل *   prt
# p21                أود *    vp
# p22                 *كلغ   prt
# p23              من فضلك   adv
# p24                 حسنا  phrs
# p25     هل تود شيئا اخر؟  phrs
# p26                 ايوا  phrs
# p27                   لا  phrs
# p28              لا شكرا  phrs
# p29  أنا لست بحاجة إليها  phrs
# p30           مع السلامة  phrs
# p31                 صحيح   adj
# p32                 خاطئ   adj
# p33                  شكر  phrs
# p34                 عفوا  phrs
# p35          هل تمتلك *؟    vp
# p36              لا افهم  phrs
# p37                    و  conj
# p38              انا اسف  phrs
# p39          هل تتكلم *؟    vp
# p40              مساعدة!  phrs

# %%
ar.to_csv("ar40.csv")
en.to_csv("en40.csv")
cn.to_csv("cn40.csv")

# %%
tri = pd.merge(en, ar, left_index=True, right_index=True)
tri = pd.merge(tri, cn, left_index=True, right_index=True)

# %%
tri = tri.rename(columns={"phrase_x": "en", "phrase_y": "ar", "phrase": "cn"})
tri = tri.drop(["pos_x","pos_y"], axis=1)

# %%
tri
# Out:
#                                 en                   ar        cn   pos
# id
# p0                           Hello                 أهلا        你好  phrs
# p1                              Hi               مرحبا         您好  phrs
# p2                         Welcome         السلام عليكم        欢迎  phrs
# p3                    Good Morning           صباح الخير       早上好  phrs
# p4                  Good Afternoon            طاب مسائك       下午好  phrs
# p5                    Good Evening           مساء الخير       晚上好  phrs
# p6            What would you like?            ماذا تحب؟    你需要什么？  phrs
# p7              What is your name?             ما اسمك؟   你叫什么名字？  phrs
# p8                    My name is *               اسمي *       我叫*    vp
# p9                Nice to meet you               تشرفنا    很高兴见到你  phrs
# p10                           good                  جيد         好   adj
# p11                         very *                 *جدا        很*   adv
# p12                          Today                اليوم        今天   adv
# p13                      We have *              لدينا *        有*    vp
# p14                         Orange               برتقال        橘子    np
# p15                          Apple                 تفاح        苹果    np
# p16                          Mango                مانجو        芒果    np
# p17                How much are *?             كم هي *؟     *多少钱？    vp
# p18             What is the price?          ماهو السعر؟      多少钱？  phrs
# p19                      * dollars            * دولارات       *块钱   prt
# p20                          per *                لكل *   每QUANT*   prt
# p21                 I would like *                أود *       我要*    vp
# p22                    * kilograms                 *كلغ       *公斤   prt
# p23                         please              من فضلك         请   adv
# p24                           okay                 حسنا         好  phrs
# p25  Would you like anything else?     هل تود شيئا اخر؟  你还需要什么吗？  phrs
# p26                            Yes                 ايوا        是的  phrs
# p27                             No                   لا        不是  phrs
# p28                     No, thanks              لا شكرا    不用了，谢谢  phrs
# p29               I don't need it.  أنا لست بحاجة إليها        不要  phrs
# p30                       Good bye           مع السلامة        再见  phrs
# p31                          Right                 صحيح         对   adj
# p32                          Wrong                 خاطئ        不对   adj
# p33                      Thank you                  شكر        谢谢  phrs
# p34                You are welcome                 عفوا       不用谢  phrs
# p35                 Do you have *?          هل تمتلك *؟     有没有*？    vp
# p36            I do not understand              لا افهم      我听不懂  phrs
# p37                            and                    و         和  conj
# p38                          Sorry              انا اسف       对不起  phrs
# p39                Do you speak *?          هل تتكلم *؟    你会说*吗？    vp
# p40                          Help!              مساعدة!      帮帮我！  phrs

# %% [markdown]
# ## Notes
# * need queries to be separated as single sentences; hard to parse otherwise

# %% [markdown]
# ---
#
# ## Jan 28 Notes
#
# ### implementing a multilingual phrase compilation model
#
# How do we build a single model that builds sentences accurately for all languages?
#
# * importance of a clean, well organized database
# * scalability of the database?
# * how to specify gender and age? through addition of more concept phrases or somehow inflecting already existing phrases?
#
# ---
