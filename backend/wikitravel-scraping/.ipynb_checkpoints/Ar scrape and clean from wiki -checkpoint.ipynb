# %% [markdown]
# ## Sentence Generation from Keywords
#
# 1. During generation-rule acquisition, generation
# rules for each keyword are automatically
# acquired.
# 2. Candidate-text sentences are constructed
# during candidate-text construction by applying
# the rules acquired in the first
# step. Each candidate-text sentence is represented
# by a graph or dependency tree.
# 3. Candidate-text sentences are ranked according
# to their scores assigned during evaluation.
# The scores are calculated as a
# probability estimated by using a keywordproduction
# model and a language model
# that are trained with a corpus.
# 4. The candidate-text sentence that maximizes
# the score or the candidate-text sentences
# whose scores are over a threshold
# are selected as output. The system can
# also output candidate-text sentences that
# are ranked within the top N sentences.

# %% [markdown]
# headword: rightmost content word
#
# content word: word whose part-of-speech is a verb, adjective,noun, demonstrative, adverb, conjunction, attribute,
#
# interjection, or undefined word.
#
# function word: everything else, formal nouns and auxiliary verbs “SURU (do)” and “NARU (become)”

# %%
import re

# %%
t = "打给 美国/澳洲/英国/加拿大 是多少钱? (<i>dǎgěi měiguó/àozhōu/yīngguó/jiānádà shì duōshǎo qián?)</i>"
hi = t.split(" (<i>")[1]
print(hi[:-5])
# Out:
# dǎgěi měiguó/àozhōu/yīngguó/jiānádà shì duōshǎo qián?

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests      

wiki = "http://wikitravel.org/en/Arabic_phrasebook"
req = requests.get(wiki)
soup = BeautifulSoup(req.text, "lxml")
    
#soup = BeautifulSoup(body, 'lxml') # Parse the HTML as a string
df = pd.DataFrame(columns=["en","ar"])
cat = ""

# %%
labels = []
for dl in soup.find_all('dl'):
    if dl.find_all('dt') and not dl.find_all('dl'):
        labels.append(dl)

# %%
ens = [] 
ars = []

df = pd.DataFrame(columns=["en","ar"])
for label in labels:
    dt = label.find_all("dt")
    dd = label.find_all("dd")
    
    for d in dd:
        if "Good night" in d.text:
            dd.remove(d)
            print("removed 1")
        
    for t in dt:
        if "antunna" in t.text:
            dt.remove(t)
            print("removed 1")
        if "(two people)" in t.text:
            dt.remove(t)
            print("removed 1")
        if "momken tfaye" in t.text:
            dt.remove(t)
            print("removed 1")
        
    if len(dt) == len(dd):
        for i in range(len(dt)):
            df.loc[len(df)] = [dt[i].text.strip(), dd[i].text.strip()]
    else:
        print(len(dt),len(dd))
        print("failed")
        print(label)
# Out:
# removed 1
# removed 1
# removed 1
# removed 1

# %%
df.to_csv("en_ar_phrases_raw.csv")

# %%
df
# Out:
#                                                     en  \
# 0                                                 OPEN
# 1                                               CLOSED
# 2                                             ENTRANCE
# 3                                                 EXIT
# 4                                                 PUSH
# 5                                                 PULL
# 6                                               TOILET
# 7                                                  MEN
# 8                                                WOMEN
# 9                                            FORBIDDEN
# 10                                             Goodbye
# 11                                  Goodbye (informal)
# 12                        I can't speak Arabic [well].
# 13                               Do you speak English?
# 14           Is there someone here who speaks English?
# 15                                               Help!
# 16                                           Look out!
# 17                                         Good night.
# 18                                 I don't understand.
# 19                                Where is the toilet?
# 20                                     Leave me alone.
# 21                                     Don't touch me!
# 22                               I'll call the police.
# 23                                             Police!
# 24                                        Stop! Thief!
# 25                                   I need your help.
# 26                                   Medical emergency
# 27                                           I'm lost.
# 28                                      I lost my bag.
# 29                                   I lost my wallet.
# ..                                                 ...
# 362                                        ...a razor.
# 363                                    ...an umbrella.
# 364                                ...sunblock lotion.
# 365                                     ...a postcard.
# 366                                 ...postage stamps.
# 367                                      ...batteries.
# 368                                  ...writing paper.
# 369                                          ...a pen.
# 370                         ...English-language books.
# 371                     ...English-language magazines.
# 372                  ...an English-language newspaper.
# 373                  ...an English-English dictionary.
# 374                              I want to rent a car.
# 375                               Can I get insurance?
# 376                            stop (on a street sign)
# 377                                            one way
# 378                                              yield
# 379                                         no parking
# 380                                        speed limit
# 381                                 gas/petrol station
# 382                                  petrol (gasoline)
# 383                                             diesel
# 384                     I haven't done anything wrong.
# 385                         It was a misunderstanding.
# 386                           Where are you taking me?
# 387                                 Am I under arrest?
# 388  I am an American/Australian/British/Canadian c...
# 389  I want to talk to the American/Australian/Brit...
# 390                        I need to talk to a lawyer.
# 391                         Can I just pay a fine now?
#
#                                                     ar
# 0                                       مفتوح (maftūh)
# 1                                       مغلق (mughlaq)
# 2                                        دخول (dukhūl)
# 3                                        خروج (khurūj)
# 4                                         ادفع (idfa`)
# 5                                         اسحب (ishab)
# 6                                        حمام (hammām)
# 7                                         رجال (rijāl)
# 8                                     سيدات (sayyidāt)
# 9                                       ممنوع (mamnū`)
# 10                          مع السلامة  ma`a as-salāma
# 11                                     باي باي bāy bāy
# 12   لا اتكلم عربي جيدا Lā atakallam `arabi [jayyidan]
# 13   Do you speak English? هل تتكلم الانجليزية hal ...
# 14   حد بيتكلم انجليزي؟ had beyetkallem ingelīzi? (...
# 15                  النجدة an-najda!; إلحقوني ilha'ūni
# 16                                       انتبه intibih
# 17                      تصبح على خير tisbah `ala khair
# 18                                    لا افهم lā afham
# 19                  وين/فين الحمام؟ ayn/fēn el-hammām?
# 20         Leave me alone. (اتركني (M) or اتركيني (F))
# 21                             لا تلمسني (lā tilmisni)
# 22            سأتصل بالشرطة.‏ ‎(sa attasil bil-shurta)
# 23   shurta, bulīs! (شرطة‎, بوليس)‎; راح اتصل بالشر...
# 24                اوقف! حرامي!‏ ‎(ūw'af, o'af harāmi!)
# 25    محتاج مساعدة لو سمحت (mihtāj musā`da law samaht)
# 26   إسعاف (is`āf); other emergencies: طوارئ (tawār...
# 27     أنا تايه (tāyeh) (M); أنا تايهة (ana tāyha) (F)
# 28                    I lost my bag. (لقد فقدت حقيبتى)
# 29                 I lost my wallet. (لقد فقدت محفظتى)
# ..                                                 ...
# 362                               ...a razor. (shafra)
# 363                        ...an umbrella. (shamseyeh)
# 364                          ...sunblock lotion. (...)
# 365                  ...بطاقة بريدية (bitaqa bareedia)
# 366                ...postage stamps. (tawabe' bareed)
# 367                          ...batteries. (batareyat)
# 368                   ...ورق للكتبة (waraq lil-kitaba)
# 369                                     ...قلم (qalam)
# 370                  ...كتب إنجليزية (kutub ingliziya)
# 371  ... مجلات انكليزية English-language magazines....
# 372               ...جرائد إنجليزية(jara'id ingliziya)
# 373  ...an English-English dictionary. (qāmūs ingil...
# 374         أريد استئجار سيارة (urīd isti'jār sayyāra)
# 375  هل أستطيع الحصول على تأمين؟ (hal astatī` al-hu...
# 376                                           قف (qif)
# 377                          اتجاه واحد (ittjāh wāhid)
# 378                                (atti alaolwyeh(?))
# 379                 ممنوع الاسطفاف (mamnū` al-istifāf)
# 380              السرعة القصوى (as-sur`a al-qānūniyya)
# 381                       محطة بنزين (mahattat banzīn)
# 382                                     بنزين (banzīn)
# 383             ديزل‎, سولار‎, جاز (dīzel, sōlār, gāz)
# 384  ما عملت اشي غلط (ma `emelet eshi ghalat) (Jord...
# 385                    كان سوء تفاهم (kān sū' tafāhom)
# 386                  وين/فين آخدني (wein/fēn akhedni?)
# 387                  هل أنا معتقل؟ (hal ana mo`taqal?)
# 388  I am an American/Australian/British/Canadian c...
# 389  I need to talk to the American/Australian/Brit...
# 390     محتاج أحكي مع محامي (mehtāj ahki ma`a mohāmi )
# 391  أقدر أدفع غرامة الآن؟ (aqdar adfa` gharāma al'...
#
# [392 rows x 2 columns]

# %%
for i, row in df.iterrows():
    if row.en in row.ar:
        row.ar = row.ar.strip(row.en).strip(" .")
    if row.en[0:3] == "...":
        row.en = row.en[3:len(row.en)-1]
    if row.ar[0:3] == "...":
        temp = row.ar.split("(")
        row.ar = temp[0][3:len(row.ar)-1]
# Out:
# ...المطار (el-matar?)
# المطار
# ...pain reliever. (mussakin)
# pain reliever.
# ...بطاقة بريدية (bitaqa bareedia)
# بطاقة بريدية
# ...ورق للكتبة (waraq lil-kitaba)
# ورق للكتبة
# ...قلم (qalam)
# قلم
# ...كتب إنجليزية (kutub ingliziya)
# كتب إنجليزية
# ...جرائد إنجليزية(jara'id ingliziya)
# جرائد إنجليزية

# %%
table = soup.find_all('table')[0] # Grab the first table

new_table = pd.DataFrame(columns=range(0,2), index = [0]) # I know the size 

row_marker = 0

for row in table.find_all('tr'):
    column_marker = 0
    columns = row.find_all('td')
    for column in columns:
        new_table.iat[row_marker,column_marker] = column.get_text()
        column_marker += 1

new_table
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-58998b6d12e7> in <module>()
# ----> 1 table = soup.find_all('table')[0] # Grab the first table
#       2
#       3 new_table = pd.DataFrame(columns=range(0,2), index = [0]) # I know the size
#       4
#       5 row_marker = 0
#
# IndexError: list index out of range

# %%
new_table
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-c53413a026c4> in <module>()
# ----> 1 new_table
#
# NameError: name 'new_table' is not defined

# %%
df
# Out:
#                        category  \
# 0                        Basics
# 1                        Basics
# 2                        Basics
# 3                        Basics
# 4                        Basics
# 5                        Basics
# 6                        Basics
# 7                        Basics
# 8                        Basics
# 9                        Basics
# 10                       Basics
# 11                       Basics
# 12                       Basics
# 13                       Basics
# 14                       Basics
# 15                       Basics
# 16                       Basics
# 17                       Basics
# 18                       Basics
# 19                       Basics
# 20                       Basics
# 21                       Basics
# 22                       Basics
# 23                       Basics
# 24                       Basics
# 25                       Basics
# 26                       Basics
# 27                       Basics
# 28                     Problems
# 29                     Problems
# ..                          ...
# 319                    Shopping
# 320                    Shopping
# 321                    Shopping
# 322                    Shopping
# 323                    Shopping
# 324                    Shopping
# 325                    Shopping
# 326                    Shopping
# 327                     Driving
# 328                     Driving
# 329                     Driving
# 330                     Driving
# 331                     Driving
# 332                     Driving
# 333                     Driving
# 334                     Driving
# 335                     Driving
# 336                     Driving
# 337                   Authority
# 338                   Authority
# 339                   Authority
# 340                   Authority
# 341                   Authority
# 342                   Authority
# 343                   Authority
# 344                   Authority
# 345  Telephone and the Internet
# 346  Telephone and the Internet
# 347  Telephone and the Internet
# 348  Telephone and the Internet
#
#                                                english  \
# 0                                              Hello.
# 1                                        How are you?
# 2                                    Fine, thank you.
# 3                May I please ask, what is your name?
# 4                                  What is your name?
# 5                                 My name is ______ .
# 6                                   Nice to meet you.
# 7                                             Please.
# 8                                          Thank you.
# 9                                     You're welcome.
# 10                     Excuse me. (getting attention)
# 11                        Excuse me. (begging pardon)
# 12                        Excuse me. (coming through)
# 13                                         I'm sorry.
# 14         It's okay. (polite response to "I'm sorry")
# 15                                            Goodbye
# 16                                 Goodbye (informal)
# 17                             I can't speak Chinese.
# 18                              Do you speak English?
# 19          Is there someone here who speaks English?
# 20                              Help! (in emergencies)
# 21                                      Good morning.
# 22                                      Good evening.
# 23                                        Good night.
# 24              I don't understand (something heard).
# 25               I don't understand (something read).
# 26                               Where is the toilet?
# 27                     Where is the bathroom（polite)?
# 28                                    Leave me alone.
# 29    I don't want it! (useful for people who come ...
# ..                                                 ...
# 319                                         ...a pen.
# 320                                      ...a pencil.
# 321                                       ...glasses.
# 322                        ...English-language books.
# 323                    ...English-language magazines.
# 324                 ...an English-language newspaper.
# 325                  ...a Chinese-English dictionary.
# 326                 ...an English-Chinese dictionary.
# 327                             I want to rent a car.
# 328                              Can I get insurance?
# 329                           stop (on a street sign)
# 330                                           one way
# 331                                             yield
# 332                                        no parking
# 333                                       speed limit
# 334                              gas (petrol) station
# 335                                            petrol
# 336                                            diesel
# 337                    I haven't done anything wrong.
# 338                        It was a misunderstanding.
# 339                          Where are you taking me?
# 340                                Am I under arrest?
# 341   I am an American/Australian/British/Canadian ...
# 342   I want to talk to the American/Australian/Bri...
# 343                       I want to talk to a lawyer.
# 344                        Can I just pay a fine now?
# 345              Can I make international calls here?
# 346   How much is it to America/Australia/Britain/C...
# 347                Where can I find an Internet cafe?
# 348                          How much is it per hour?
#
#                                                chinese
# 0                                          你好。 Nǐ hǎo.
# 1                                      你好吗？ Nǐ hǎo ma?
# 2                             很好, 谢谢。 Hěn hǎo, xièxie.
# 3                 请问你叫什么名? Qǐngwèn nǐjiào shěnme míng?
# 4                       你叫什么名字？ Nǐ jiào shénme míngzi?
# 5                         我叫 _____ 。 Wǒ jiào ______ .
# 6                       很高兴认识你。 Hěn gāoxìng rènshì nǐ.
# 7                                             请。 Qǐng.
# 8                                          谢谢。 Xièxiè.
# 9                                        不客气。 Bú kèqi.
# 10                                         请问 qǐng wèn
# 11             打扰一下。 Dǎrǎo yixià ; 麻烦您了, Máfán nín le.
# 12             对不起 Duìbùqǐ * or * 请让一下 Qǐng ràng yixià
# 13                                       对不起。 Duìbùqǐ.
# 14                                    没关系 (méiguānxi).
# 15                                         再见。 Zàijiàn
# 16                               拜拜。 Bāi-bāi (Bye bye)
# 17                   我不会讲中文。 Wǒ bú huì jiáng zhōngwén.
# 18                      你会说英语吗？ Nǐ huì shuō Yīngyǔ ma?
# 19        这里有人会说英语吗？ Zhèlĭ yǒu rén hùi shuō Yīngyǔ ma?
# 20                                        救命！ Jiùmìng!
# 21                                         早安。 zǎo ān.
# 22                                  晚上好。 Wǎnshàng hǎo.
# 23                                         晚安。 Wǎn'ān.
# 24                              我听不懂。 Wǒ tīng bù dǒng.
# 25                               我看不懂。 Wǒ kàn bù dǒng.
# 26                              厕所在哪里？ Cèsuǒ zài nǎli?
# 27                        洗手间在哪里？ Xǐshǒujiān zài nǎli?
# 28                             不要打扰我。 (búyào dǎrǎo wǒ)
# 29                                     我不要 (wǒ búyào!)
# ..                                                 ...
# 319                                             笔 (bǐ)
# 320                                        铅笔 (qiānbǐ)
# 321                                       眼镜 (yǎnjìng)
# 322                                  英文书 (Yīngwén shū)
# 323                               英文杂志 (Yīngwén zázhì)
# 324                              英文报纸 (Yīngwén bàozhǐ)
# 325                             汉英词典 (Hàn-Yīng cídiǎn)
# 326                             英汉词典 (Yīng-Hàn cídiǎn)
# 327                         我想要租车。 (wǒ xiǎngyào zūchē)
# 328                 我可以买保险吗？ (wǒ kěyǐ mǎi bǎoxiǎn ma?)
# 329                                           停 (tíng)
# 330                                   单行道 (dānxíngdào)
# 331                                        让路 (rànglù)
# 332                               禁止停车 (jìnzhǐ tíngchē
# 333                                速度限制 (sùdù xiànzhì)
# 334                                   加油站 (jiāyóuzhàn)
# 335                                         汽油 (qìyóu)
# 336                                       柴油 (cháiyóu)
# 337                     我没有做错事。 (wǒ méiyǒu zuòcuò shì)
# 338                              这是误会。 (zhè shì wùhuì)
# 339                       你带我去哪里？ (nǐ dài wǒ qù nǎlǐ?)
# 340                            我被捕了吗？ (wǒ bèibǔle ma?)
# 341   我是 美国/澳洲/英国/加拿大 公民。 (wǒ shì měiguó/àozhōu/yīn...
# 342   我希望跟 美国/澳洲/英国/加拿大 的 大使馆/领事馆 联系。 (wǒ xīwàng gē...
# 343             我希望跟律师联系。 (wǒ xīwàng gēn lǜshī liánxì)
# 344              我可以支付罚款吗？ (wǒ kěyǐ zhī fù fákuǎn ma?)
# 345              可以打国际电话吗? (kěyǐ dǎ guójì diànhuà ma?)
# 346   打给 美国/澳洲/英国/加拿大 是多少钱? (dǎgěi měiguó/àozhōu/yī...
# 347                         哪里有网吧? (nǎlǐ yǒu wǎng ba?)
# 348           一小时是多少钱?  (yī xiǎoshí shì duōshǎo qián?)
#
# [349 rows x 3 columns]

# %%
df.category.unique()
# Out:
# array(['Basics', 'Problems', 'Going to the doctor', 'Numbers', 'Time',
#        'Colours', 'Transportation', 'Lodging', 'Money', 'Eating', 'Bars',
#        'Shopping', 'Driving', 'Authority', 'Telephone and the Internet'], dtype=object)

# %%
count = 0
validIndex = []

df1 = df.copy()

for index, row in df.iterrows():
    sepList = ["？", "。", " (", "！","?", "," , "  "]
    
    for sep in sepList:
        if sep in row["chinese"]:
            if sep == " (":
                row['chinese'] = (row['chinese'].split(sep)[0])
            else:
                row['chinese'] = (row['chinese'].split(sep)[0]+sep)
            count += 1
            validIndex.append(index)
            break
        
print(count)
# Out:
# 236

# %%
c = 0
for index, row in df.iterrows():
    if index not in validIndex:
        sp = row.chinese.split()
        if len(sp) > 1 and sp[1][0].isalpha():
            row['chinese'] = sp[0]
# Out:
# 请问
# 对不起
# 十一
# 十二
# 十三
# 十四
# 十五
# 十六
# 十七
# 十八
# 十九
# 二十
# 二十一
# 二十二
# 二十三
# 三十
# 四十
# 五十
# 六十
# 七十
# 八十
# 九十
# 一百一十一
# 二百
# 三百
# 五百
# 二千
# or
# 一万〇一
# 一万〇二
# 二万
# 五万
# 十万
# 二十万
# 一百万
# 一千万
# 一兆
# 半
# 少於
# 多於
# 更
# 现在
# 以后
# 下午3点半.
# 下午3点38分
# _____
# _____
# _____
# _____
# _____
# _____
# 今天
# 昨天
#  前天qiăntiān
#  柳橙汁 （liǔchéng zhī)

# %%
t = "左边 zuǒbiān"

# %%
t1 = t.split()[1]

# %%
t2 = t1[0]

# %%
t2.isalpha()
# Out:
# True

# %%
df.to_csv("cleaned_chinese.csv")
