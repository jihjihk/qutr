# %%
import pandas as pd

# %%
cn = pd.read_csv('clean_en_cn.tsv', sep='\t', usecols=['category', 'english','chinese'])

# %%
cn
# Out:
#                        category  \
# 0                        Basics
# 1                        Basics
# 2                        Basics
# 3                        Basics
# 4                        Basics
# 5                        Basics
# 6                        Basics
# 7                        Basics
# 8                        Basics
# 9                        Basics
# 10                       Basics
# 11                       Basics
# 12                       Basics
# 13                       Basics
# 14                       Basics
# 15                       Basics
# 16                       Basics
# 17                       Basics
# 18                       Basics
# 19                       Basics
# 20                       Basics
# 21                       Basics
# 22                       Basics
# 23                       Basics
# 24                       Basics
# 25                       Basics
# 26                       Basics
# 27                       Basics
# ...

# %%
cn.columns
# Out:
# Index(['Unnamed: 0', 'category', 'english', 'chinese'], dtype='object')

# %%
cn.columns
# Out:
# Index(['Unnamed: 0', 'category', 'english', 'chinese'], dtype='object')
