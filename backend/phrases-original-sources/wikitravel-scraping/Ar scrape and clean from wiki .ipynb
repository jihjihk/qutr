# %% [markdown]
# ## Sentence Generation from Keywords
#
# 1. During generation-rule acquisition, generation
# rules for each keyword are automatically
# acquired.
# 2. Candidate-text sentences are constructed
# during candidate-text construction by applying
# the rules acquired in the first
# step. Each candidate-text sentence is represented
# by a graph or dependency tree.
# 3. Candidate-text sentences are ranked according
# to their scores assigned during evaluation.
# The scores are calculated as a
# probability estimated by using a keywordproduction
# model and a language model
# that are trained with a corpus.
# 4. The candidate-text sentence that maximizes
# the score or the candidate-text sentences
# whose scores are over a threshold
# are selected as output. The system can
# also output candidate-text sentences that
# are ranked within the top N sentences.

# %% [markdown]
# headword: rightmost content word
#
# content word: word whose part-of-speech is a verb, adjective,noun, demonstrative, adverb, conjunction, attribute,
#
# interjection, or undefined word.
#
# function word: everything else, formal nouns and auxiliary verbs “SURU (do)” and “NARU (become)”

# %%
import re

# %%
t = "打给 美国/澳洲/英国/加拿大 是多少钱? (<i>dǎgěi měiguó/àozhōu/yīngguó/jiānádà shì duōshǎo qián?)</i>"
hi = t.split(" (<i>")[1]
print(hi[:-5])
# Out:
# dǎgěi měiguó/àozhōu/yīngguó/jiānádà shì duōshǎo qián?

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests      

wiki = "http://wikitravel.org/en/Arabic_phrasebook"
req = requests.get(wiki)
soup = BeautifulSoup(req.text, "lxml")
    
#soup = BeautifulSoup(body, 'lxml') # Parse the HTML as a string
df = pd.DataFrame(columns=["en","ar"])
cat = ""

# %%
labels = []
for dl in soup.find_all('dl'):
    if dl.find_all('dt') and not dl.find_all('dl'):
        labels.append(dl)

# %%
ens = [] 
ars = []

df = pd.DataFrame(columns=["en","ar"])
for label in labels:
    dt = label.find_all("dt")
    dd = label.find_all("dd")
    
    for d in dd:
        if "Good night" in d.text:
            dd.remove(d)
            print("removed 1")
        
    for t in dt:
        if "antunna" in t.text:
            dt.remove(t)
            print("removed 1")
        if "(two people)" in t.text:
            dt.remove(t)
            print("removed 1")
        if "momken tfaye" in t.text:
            dt.remove(t)
            print("removed 1")
        
    if len(dt) == len(dd):
        for i in range(len(dt)):
            df.loc[len(df)] = [dt[i].text.strip(), dd[i].text.strip()]
    else:
        print(len(dt),len(dd))
        print("failed")
        print(label)
# Out:
# removed 1
# removed 1
# removed 1
# removed 1

# %%
df.to_csv("en_ar_phrases_raw.csv")

# %%
df
# Out:
#                                                     en  \
# 0                                                 OPEN
# 1                                               CLOSED
# 2                                             ENTRANCE
# 3                                                 EXIT
# 4                                                 PUSH
# 5                                                 PULL
# 6                                               TOILET
# 7                                                  MEN
# 8                                                WOMEN
# 9                                            FORBIDDEN
# 10                                             Goodbye
# 11                                  Goodbye (informal)
# 12                        I can't speak Arabic [well].
# 13                               Do you speak English?
# 14           Is there someone here who speaks English?
# 15                                               Help!
# 16                                           Look out!
# 17                                         Good night.
# 18                                 I don't understand.
# 19                                Where is the toilet?
# 20                                     Leave me alone.
# 21                                     Don't touch me!
# 22                               I'll call the police.
# 23                                             Police!
# 24                                        Stop! Thief!
# 25                                   I need your help.
# 26                                   Medical emergency
# 27                                           I'm lost.
# 28                                      I lost my bag.
# 29                                   I lost my wallet.
# ..                                                 ...
# 362                                        ...a razor.
# 363                                    ...an umbrella.
# 364                                ...sunblock lotion.
# 365                                     ...a postcard.
# 366                                 ...postage stamps.
# 367                                      ...batteries.
# 368                                  ...writing paper.
# 369                                          ...a pen.
# 370                         ...English-language books.
# 371                     ...English-language magazines.
# 372                  ...an English-language newspaper.
# 373                  ...an English-English dictionary.
# 374                              I want to rent a car.
# 375                               Can I get insurance?
# 376                            stop (on a street sign)
# 377                                            one way
# 378                                              yield
# 379                                         no parking
# 380                                        speed limit
# 381                                 gas/petrol station
# 382                                  petrol (gasoline)
# 383                                             diesel
# 384                     I haven't done anything wrong.
# 385                         It was a misunderstanding.
# 386                           Where are you taking me?
# 387                                 Am I under arrest?
# 388  I am an American/Australian/British/Canadian c...
# 389  I want to talk to the American/Australian/Brit...
# 390                        I need to talk to a lawyer.
# 391                         Can I just pay a fine now?
#
#                                                     ar
# 0                                       مفتوح (maftūh)
# 1                                       مغلق (mughlaq)
# 2                                        دخول (dukhūl)
# 3                                        خروج (khurūj)
# 4                                         ادفع (idfa`)
# 5                                         اسحب (ishab)
# 6                                        حمام (hammām)
# 7                                         رجال (rijāl)
# 8                                     سيدات (sayyidāt)
# 9                                       ممنوع (mamnū`)
# 10                          مع السلامة  ma`a as-salāma
# 11                                     باي باي bāy bāy
# 12   لا اتكلم عربي جيدا Lā atakallam `arabi [jayyidan]
# 13   Do you speak English? هل تتكلم الانجليزية hal ...
# 14   حد بيتكلم انجليزي؟ had beyetkallem ingelīzi? (...
# 15                  النجدة an-najda!; إلحقوني ilha'ūni
# 16                                       انتبه intibih
# 17                      تصبح على خير tisbah `ala khair
# 18                                    لا افهم lā afham
# 19                  وين/فين الحمام؟ ayn/fēn el-hammām?
# 20         Leave me alone. (اتركني (M) or اتركيني (F))
# 21                             لا تلمسني (lā tilmisni)
# 22            سأتصل بالشرطة.‏ ‎(sa attasil bil-shurta)
# 23   shurta, bulīs! (شرطة‎, بوليس)‎; راح اتصل بالشر...
# 24                اوقف! حرامي!‏ ‎(ūw'af, o'af harāmi!)
# 25    محتاج مساعدة لو سمحت (mihtāj musā`da law samaht)
# 26   إسعاف (is`āf); other emergencies: طوارئ (tawār...
# 27     أنا تايه (tāyeh) (M); أنا تايهة (ana tāyha) (F)
# 28                    I lost my bag. (لقد فقدت حقيبتى)
# 29                 I lost my wallet. (لقد فقدت محفظتى)
# ..                                                 ...
# 362                               ...a razor. (shafra)
# 363                        ...an umbrella. (shamseyeh)
# 364                          ...sunblock lotion. (...)
# 365                  ...بطاقة بريدية (bitaqa bareedia)
# 366                ...postage stamps. (tawabe' bareed)
# 367                          ...batteries. (batareyat)
# 368                   ...ورق للكتبة (waraq lil-kitaba)
# 369                                     ...قلم (qalam)
# 370                  ...كتب إنجليزية (kutub ingliziya)
# 371  ... مجلات انكليزية English-language magazines....
# 372               ...جرائد إنجليزية(jara'id ingliziya)
# 373  ...an English-English dictionary. (qāmūs ingil...
# 374         أريد استئجار سيارة (urīd isti'jār sayyāra)
# 375  هل أستطيع الحصول على تأمين؟ (hal astatī` al-hu...
# 376                                           قف (qif)
# 377                          اتجاه واحد (ittjāh wāhid)
# 378                                (atti alaolwyeh(?))
# 379                 ممنوع الاسطفاف (mamnū` al-istifāf)
# 380              السرعة القصوى (as-sur`a al-qānūniyya)
# 381                       محطة بنزين (mahattat banzīn)
# 382                                     بنزين (banzīn)
# 383             ديزل‎, سولار‎, جاز (dīzel, sōlār, gāz)
# 384  ما عملت اشي غلط (ma `emelet eshi ghalat) (Jord...
# 385                    كان سوء تفاهم (kān sū' tafāhom)
# 386                  وين/فين آخدني (wein/fēn akhedni?)
# 387                  هل أنا معتقل؟ (hal ana mo`taqal?)
# 388  I am an American/Australian/British/Canadian c...
# 389  I need to talk to the American/Australian/Brit...
# 390     محتاج أحكي مع محامي (mehtāj ahki ma`a mohāmi )
# 391  أقدر أدفع غرامة الآن؟ (aqdar adfa` gharāma al'...
#
# [392 rows x 2 columns]

# %%
for i, row in df.iterrows():
    if row.en in row.ar:
        row.ar = row.ar.strip(row.en).strip(" .")
    if row.en[0:3] == "...":
        row.en = row.en[3:len(row.en)-1]
    if row.ar[0:3] == "...":
        temp = row.ar.split("(")
        row.ar = temp[0][3:len(row.ar)-1]
    
    brack = re.compile(r'\(.*\)')
    unders = re.compile(r'_+')
    eng = re.compile(r'[a-zA-Z0-9āīūēō\-.,~\'`?!\[\]]+')
    row.ar = brack.sub("", row.ar)
    row.ar = unders.sub("*", row.ar)
    row.ar = eng.sub("", row.ar)

# %%
df
# Out:
#                                                     en  \
# 0                                                 OPEN
# 1                                               CLOSED
# 2                                             ENTRANCE
# 3                                                 EXIT
# 4                                                 PUSH
# 5                                                 PULL
# 6                                               TOILET
# 7                                                  MEN
# 8                                                WOMEN
# 9                                            FORBIDDEN
# 10                                             Goodbye
# 11                                  Goodbye (informal)
# 12                        I can't speak Arabic [well].
# 13                               Do you speak English?
# 14           Is there someone here who speaks English?
# 15                                               Help!
# 16                                           Look out!
# 17                                         Good night.
# 18                                 I don't understand.
# 19                                Where is the toilet?
# 20                                     Leave me alone.
# 21                                     Don't touch me!
# 22                               I'll call the police.
# 23                                             Police!
# 24                                        Stop! Thief!
# 25                                   I need your help.
# 26                                   Medical emergency
# 27                                           I'm lost.
# 28                                      I lost my bag.
# 29                                   I lost my wallet.
# ..                                                 ...
# 362                                            a razor
# 363                                        an umbrella
# 364                                    sunblock lotion
# 365                                         a postcard
# 366                                     postage stamps
# 367                                          batteries
# 368                                      writing paper
# 369                                              a pen
# 370                             English-language books
# 371                         English-language magazines
# 372                      an English-language newspaper
# 373                      an English-English dictionary
# 374                              I want to rent a car.
# 375                               Can I get insurance?
# 376                            stop (on a street sign)
# 377                                            one way
# 378                                              yield
# 379                                         no parking
# 380                                        speed limit
# 381                                 gas/petrol station
# 382                                  petrol (gasoline)
# 383                                             diesel
# 384                     I haven't done anything wrong.
# 385                         It was a misunderstanding.
# 386                           Where are you taking me?
# 387                                 Am I under arrest?
# 388  I am an American/Australian/British/Canadian c...
# 389  I want to talk to the American/Australian/Brit...
# 390                        I need to talk to a lawyer.
# 391                         Can I just pay a fine now?
#
#                                ar
# 0                          مفتوح
# 1                           مغلق
# 2                           دخول
# 3                           خروج
# 4                           ادفع
# 5                           اسحب
# 6                           حمام
# 7                           رجال
# 8                          سيدات
# 9                          ممنوع
# 10                  مع السلامة
# 11                      باي باي
# 12         لا اتكلم عربي جيدا
# 13         هل تتكلم الانجليزية
# 14         حد بيتكلم انجليزي؟
# 15              النجدة ; إلحقوني
# 16                         انتبه
# 17                تصبح على خير
# 18                      لا افهم
# 19             وين/فين الحمام؟ /
# 20
# 21                     لا تلمسني
# 22               سأتصل بالشرطة‏ ‎
# 23
# 24                  اوقف حرامي‏ ‎
# 25          محتاج مساعدة لو سمحت
# 26                         إسعاف
# 27                      أنا تايه
# 28
# 29
# ..                            ...
# 362
# 363
# 364
# 365                 بطاقة بريدية
# 366
# 367
# 368                   ورق للكتبة
# 369                          قلم
# 370                 كتب إنجليزية
# 371             مجلات انكليزية
# 372                جرائد إنجليزية
# 373
# 374           أريد استئجار سيارة
# 375  هل أستطيع الحصول على تأمين؟
# 376                           قف
# 377                   اتجاه واحد
# 378
# 379               ممنوع الاسطفاف
# 380                السرعة القصوى
# 381                   محطة بنزين
# 382                        بنزين
# 383             ديزل‎ سولار‎ جاز
# 384              ما عملت اشي غلط
# 385                كان سوء تفاهم
# 386                وين/فين آخدني
# 387                هل أنا معتقل؟
# 388
# 389                        /// /
# 390          محتاج أحكي مع محامي
# 391        أقدر أدفع غرامة الآن؟
#
# [392 rows x 2 columns]

# %%
df.to_csv("cleaned_arabic.csv")

# %%
cndf = pd.read_csv("../clean_en_cn.tsv", sep="\t")

# %%
cndf= cndf.drop(['Unnamed: 0','category'], axis=1)

# %%
ardf = df.copy()
cndf = cndf.rename(columns={"english": "en", "chinese": "cn"})

# %%
for i, row in cndf.iterrows():
    row.en = row.en.strip()
    row.cn = row.cn.strip()
    if row.en[0:3] == "...":
        row.en = row.en[3:len(row.en)-2]
        defart = ["the ","a ","an "]
        for artc in defart:
            if artc in row.en:
                row.en = row.en.replace(artc, "")
    
    if row.cn[0:3] == "...":
        row.cn = row.cn[3:len(row.cn)-2]
    
for i,row in ardf.iterrows():
    row.en = row.en.strip()
    row.ar = row.ar.strip()

# %%
cndf
# Out:
#                                                     en  \
# 0                                               Hello.
# 1                                         How are you?
# 2                                     Fine, thank you.
# 3                 May I please ask, what is your name?
# 4                                   What is your name?
# 5                                       My name is * .
# 6                                    Nice to meet you.
# 7                                              Please.
# 8                                           Thank you.
# 9                                      You're welcome.
# 10                      Excuse me. (getting attention)
# 11                         Excuse me. (begging pardon)
# 12                         Excuse me. (coming through)
# 13                                          I'm sorry.
# 14         It's okay. (polite response to "I'm sorry")
# 15                                             Goodbye
# 16                                  Goodbye (informal)
# 17                              I can't speak Chinese.
# 18                               Do you speak English?
# 19           Is there someone here who speaks English?
# 20                              Help! (in emergencies)
# 21                                       Good morning.
# 22                                       Good evening.
# 23                                         Good night.
# 24               I don't understand (something heard).
# 25                I don't understand (something read).
# 26                                Where is the toilet?
# 27                      Where is the bathroom（polite)?
# 28                                     Leave me alone.
# 29   I don't want it! (useful for people who come u...
# ..                                                 ...
# 318                                                 pe
# 319                                              penci
# 320                                             glasse
# 321                              English-language book
# 322                          English-language magazine
# 323                          English-language newspape
# 324                          Chinese-English dictionar
# 325                          English-Chinese dictionar
# 326                              I want to rent a car.
# 327                               Can I get insurance?
# 328                            stop (on a street sign)
# 329                                            one way
# 330                                              yield
# 331                                         no parking
# 332                                        speed limit
# 333                               gas (petrol) station
# 334                                             petrol
# 335                                             diesel
# 336                     I haven't done anything wrong.
# 337                         It was a misunderstanding.
# 338                           Where are you taking me?
# 339                                 Am I under arrest?
# 340  I am an American/Australian/British/Canadian c...
# 341  I want to talk to the American/Australian/Brit...
# 342                        I want to talk to a lawyer.
# 343                         Can I just pay a fine now?
# 344               Can I make international calls here?
# 345  How much is it to America/Australia/Britain/Ca...
# 346                 Where can I find an Internet cafe?
# 347                           How much is it per hour?
#
#                                   cn
# 0                                你好。
# 1                               你好吗？
# 2                            很好, 谢谢。
# 3                           请问你叫什么名?
# 4                            你叫什么名字？
# 5                             我叫 * 。
# 6                            很高兴认识你。
# 7                                 请。
# 8                                谢谢。
# 9                               不客气。
# 10                                请问
# 11                             打扰一下。
# 12                               对不起
# 13                              对不起。
# 14                               没关系
# 15                               再见。
# 16                               拜拜。
# 17                           我不会讲中文。
# 18                           你会说英语吗？
# 19                        这里有人会说英语吗？
# 20                               救命！
# 21                               早安。
# 22                              晚上好。
# 23                               晚安。
# 24                             我听不懂。
# 25                             我看不懂。
# 26                            厕所在哪里？
# 27                           洗手间在哪里？
# 28                            不要打扰我。
# 29                               我不要
# ..                               ...
# 318                                笔
# 319                               铅笔
# 320                               眼镜
# 321                              英文书
# 322                             英文杂志
# 323                             英文报纸
# 324                             汉英词典
# 325                             英汉词典
# 326                           我想要租车。
# 327                         我可以买保险吗？
# 328                                停
# 329                              单行道
# 330                               让路
# 331                             禁止停车
# 332                             速度限制
# 333                              加油站
# 334                               汽油
# 335                               柴油
# 336                          我没有做错事。
# 337                            这是误会。
# 338                          你带我去哪里？
# 339                           我被捕了吗？
# 340              我是 美国/澳洲/英国/加拿大 公民。
# 341  我希望跟 美国/澳洲/英国/加拿大 的 大使馆/领事馆 联系。
# 342                        我希望跟律师联系。
# 343                        我可以支付罚款吗？
# 344                        可以打国际电话吗?
# 345            打给 美国/澳洲/英国/加拿大 是多少钱?
# 346                           哪里有网吧?
# 347                         一小时是多少钱?
#
# [348 rows x 2 columns]

# %%
pd.merge?

# %%
result = pd.merge(ardf, cndf, how='outer', on=['en'])`

# %%
len(result)
# Out:
# 563

# %%
result.sort_values("en")
# Out:
#                                          en                ar       cn
# 318                          (bubbly) water        مياه غازية      NaN
# 307                           (fresh) fruit                 )      NaN
# 306                      (fresh) vegetables                 )      NaN
# 527  * (hard liquor) and * (mixer), please.               NaN  请给我*和*。
# 478                                * day(s)               NaN      * 天
# 477                               * hour(s)               NaN     * 小时
# 476                             * minute(s)               NaN     * 分钟
# 480                              * month(s)               NaN      * 月
# 479                               * week(s)               NaN     * 星期
# 481                               * year(s)               NaN      * 年
# 46                                        0               صفر        〇
# 47                                        1              واحد        一
# 83                                1,000,000             مليون      一百万
# 84                            1,000,000,000      مليار‎ بليون      NaN
# 85                        1,000,000,000,000           تريليون       一兆
# 56                                       10              عشرة        十
# 460                                  10,000               NaN       一万
# 467                              10,000,000               NaN      一千万
# 461                                  10,001               NaN     一万〇一
# 462                                  10,002               NaN     一万〇二
# 77                                      100               مئة       一百
# 465                                 100,000               NaN       十万
# 468                             100,000,000               NaN       一亿
# 80                                     1000               الف       一千
# 456                                     101               NaN     一百〇一
# 57                                       11           احد عشر       十一
# 457                                     110               NaN     一百一十
# 458                                     111               NaN    一百一十一
# 58                                       12          اثنا عشر       十二
# 59                                       13         ثلاثة عشر       十三
# ..                                      ...               ...      ...
# 145                                   water               ماء        水
# 146                                   water               ماء        水
# 147                                   water    ماي‎ ماية‎ ماء        水
# 150                                   water               ماء        水
# 149                                   water               ماء        水
# 148                                   water    ماي‎ ماية‎ ماء        水
# 114                                      we  نحن ; احنا‎ نحنا      NaN
# 242                                    west               غرب        西
# 336                                 whiskey                        威士忌
# 200                                   white              أبيض       白色
# 153                                    work               شغل      NaN
# 547                            writing pape               NaN        纸
# 373                           writing paper        ورق للكتبة      NaN
# 204                                  yellow              أصفر       黄色
# 175                               yesterday               أمس       昨天
# 383                                   yield                         让路
# 111                                 you (f)            أنتِ ;      NaN
# 110                                 you (m)            أنتَ ;      NaN
# 115                           you (m/mixed)             أنتما      NaN
# 291                              à la carte                        NaN
# 36                                        ٠                        NaN
# 37                                        ١                        NaN
# 38                                        ٢                        NaN
# 39                                        ٣                        NaN
# 40                                        ٤                        NaN
# 41                                        ٥                        NaN
# 42                                        ٦                        NaN
# 43                                        ٧                        NaN
# 44                                        ٨                        NaN
# 45                                        ٩                        NaN
#
# [563 rows x 3 columns]

# %%
nodup = result.drop_duplicates().sort_values("en")

# %%
nodup.to_csv("cleaned_merged.csv")
